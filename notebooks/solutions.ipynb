# %% [markdown]
# # 📓 Data Science Homework
# Fill in the code blocks and markdown cells as instructed below.

# %% [markdown]
# ## Descriptive Statistics

# %%
# TODO: Load the dataset and compute mean, median, mode, std, IQR

import pandas as pd
import numpy as np
nv = pd.read_csv('../data/ACCIDENTS_GU_BCN_2013.csv')
victims = nv['N�mero de v�ctimes']
print('The average number of victims is: ', victims.mean())
print('The median number of victims is: ', victims.median())
print('The mode is: ', victims.mode())
victims_std = nv['N�mero de v�ctimes'].std()
print('The standard deviation is: ', victims_std)
victims_iqr = nv['N�mero de v�ctimes'].quantile()
print('The Inner Quantile Range is: ', victims_iqr)
# Out:
# The average number of victims is:  1.2070424024532094
# The median number of victims is:  1.0
# The mode is:  0    1
# Name: N�mero de v�ctimes, dtype: int64
# The standard deviation is:  0.8005795130298843
# The Inner Quantile Range is:  1.0

# %% [markdown]
# ## Visualizations (Histogram, KDE, Boxplot, Heatmap)

# %%
# TODO: Plot histogram, KDE, boxplot, and correlation heatmap

import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(victims, bins=15, kde=False)
plt.title('Histogram')
plt.show()

sns.kdeplot(victims, fill=True)
plt.title('KDE Plot')
plt.show()

sns.boxplot(x=victims)
plt.title('Boxplot')
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 18
#      15 plt.show()
#      17 plt.figure(figsize=(10,6))
# ---> 18 sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
#      19 plt.title('Heatmap')
#      20 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Bootstrap Confidence Interval

# %%
# TODO: Bootstrap sample mean and CI (e.g., for 'Número de víctimes')

boot_means = [victims.sample(frac=1, replace=True).mean() for _ in range(1000)]
ci_lower = np.percentile(boot_means, 7.5)
ci_upper = np.percentile(boot_means, 92.5)
print(f'95% CI for mean victims: ({ci_lower:.2f}, {ci_upper:.2f})')
# Out:
# 95% CI for mean victims: (1.20, 1.22)
# Mean estimate:  0.0

# %% [markdown]
# ## Hypothesis Testing

# %%
# TODO: Perform a t-test (e.g., is mean != 1?) and interpret the result

from scipy.stats import ttest_1samp
t_stat, p_val = ttest_1samp(victims.dropna(), popmean=1)
print(f't-statistic: {t_stat:.2f}, p-value: {p_val:.4f}')
if p_val < 0.05:
    print('Reject null hypothesis: mean is significantly different from 1')
else:
    print('Fail to reject null hypothesis')
# Out:
# t-statistic: 25.15, p-value: 0.0000
# Reject null hypothesis: mean is significantly different from 1
